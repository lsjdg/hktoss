# %%
import pandas as pd
import os
import seaborn as sns

# %%
url = '../kaggle/playground-series-s4e7/'

def read_csv_file(str):
    return pd.read_csv(f'{url}{str}.csv')

# %%
test = read_csv_file('test')
train = read_csv_file('train')
sample_submission = read_csv_file('sample_submission')

# %%
train.loc[train['Response'] == 0].reset_index(drop=True)
# Out:
#                 id  Gender  Age  Driving_License  Region_Code  \
# 0                0    Male   21                1         35.0
# 1                2  Female   25                1         14.0
# 2                3  Female   35                1          1.0
# 3                4  Female   36                1         15.0
# 4                5  Female   31                1         47.0
# ...            ...     ...  ...              ...          ...
# 10089734  11504791  Female   31                1         32.0
# 10089735  11504792    Male   34                1         28.0
# 10089736  11504793    Male   48                1          6.0
# 10089737  11504795  Female   29                1         32.0
# 10089738  11504797    Male   25                1         28.0
#
#           Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                          0    1-2 Year            Yes         65101.0
# 1                          1    < 1 Year             No         38043.0
# ...

# %%
train.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')
