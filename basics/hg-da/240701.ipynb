# %%
import pandas as pd
import seaborn as sns

# %%
print(pd.__version__)
print(sns.__version__)
# Out:
# 2.1.4
# 0.12.2

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.shape[0] + iris.shape[1]
# Out:
# 155

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['sepal_length'].value_counts()
# Out:
# sepal_length
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df = iris.drop('species', axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris.shape, df.shape
# Out:
# ((150, 5), (150, 4))

# %%
df = iris.drop(['sepal_length', 'sepal_width'], axis = 1)
df.head()
# Out:
#    petal_length  petal_width species
# 0           1.4          0.2  setosa
# 1           1.4          0.2  setosa
# 2           1.3          0.2  setosa
# 3           1.5          0.2  setosa
# 4           1.4          0.2  setosa

# %%
iris['petal_length'][0]
# Out:
# 1.4

# %%
iris['petal_length']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
# 파일 내보내기

# %%
iris.to_csv("iris.csv")
iris.to_csv("iris2.csv", index = False) # index 가 적힌 column 없다 => 더 많이 사용

# %%
iris.to_csv('../test_data/iris.csv', index = False)

# %%
# 파일 불러오기

# %%
iris_df = pd.read_csv('../test_data/iris.csv')
iris_df.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
test = pd.read_csv('../kaggle/playground_series/test.csv')
test.head()
# Out:
#          id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  11504798  Female   20                1         47.0                   0
# 1  11504799    Male   47                1         28.0                   0
# 2  11504800    Male   47                1         43.0                   0
# 3  11504801  Female   22                1         47.0                   1
# 4  11504802    Male   51                1         19.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No          2630.0                 160.0      228
# 1    1-2 Year            Yes         37483.0                 124.0      123
# 2    1-2 Year            Yes          2630.0                  26.0      271
# 3    < 1 Year             No         24502.0                 152.0      115
# 4    1-2 Year             No         34115.0                 124.0      148

# %%
train = pd.read_csv('../kaggle/playground_series/train.csv')
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
submission = pd.read_csv('../kaggle/playground_series/sample_submission.csv')
submission.head()
# Out:
#          id  Response
# 0  11504798       0.5
# 1  11504799       0.5
# 2  11504800       0.5
# 3  11504801       0.5
# 4  11504802       0.5

# %%
# iris.loc[행, 열]

# %%
iris.loc[:, ['sepal_length', 'species']] # 모든 행 선택
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %%
cols = ['sepal_length', 'species']
iris.loc[iris['sepal_length'] >= 7.5, cols]
# Out:
#      sepal_length    species
# 105           7.6  virginica
# 117           7.7  virginica
# 118           7.7  virginica
# 122           7.7  virginica
# 131           7.9  virginica
# 135           7.7  virginica

# %%
cols = ['sepal_width', 'petal_length']
iris.loc[iris['petal_length'] >= 1.7, cols].reset_index(drop=True)
# Out:
#      sepal_width  petal_length
# 0            3.9           1.7
# 1            3.8           1.7
# 2            3.4           1.7
# 3            3.3           1.7
# 4            3.4           1.9
# ..           ...           ...
# 101          3.0           5.2
# 102          2.5           5.0
# 103          3.0           5.2
# 104          3.4           5.4
# 105          3.0           5.1
#
# [106 rows x 2 columns]

# %%
# 다중조건 : and, or 연산자

# %%
cols = ['sepal_width', 'petal_length']
result = iris.loc[(iris['species'] == 'setosa') & (iris['sepal_length'] <= 5.1), cols].reset_index(drop = True)
result.shape
# Out:
# (36, 2)

# %%
test.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage'],
#       dtype='object')

# %%
train.loc[train['Gender'] == 'Male'].shape[0]
# Out:
# 6228134

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
train.loc[train['Vehicle_Age'].isin(['1-2 Year', '< 1 Year'])].shape[0]
# Out:
# 11026823
