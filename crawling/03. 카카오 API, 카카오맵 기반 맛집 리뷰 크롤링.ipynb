# %%
import requests

REST_API_KEY = '2fa4da0b370eee3234c565b78ecff325'
# url 의 ? 뒤쪽은 쿼리 파라미터
# keyword의 주변 반경 1km 내의 맛집 찾기
KEYWORD_LOCAL_URL = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}&radius=1000'

keywords=['성수역', '신촌역']

# %%
# header 에 인증 정보 추가 (안하면 401 error)
headers = {
    'Authorization' : f'KakaoAK {REST_API_KEY}'
}
response = requests.get(KEYWORD_LOCAL_URL.format(keywords[0] + '맛집'), headers=headers)
response
# Out:
# <Response [200]>

# %%
# 카카오에서 JSON으로 데이터를 준다는 것을 알고 있음
# content 말고 json()으로 바로 뽑아올 수 있다

data = response.json()['documents'] # 장소 정보를 가져옴
data
# Out:
# [{'address_name': '서울 성동구 성수동2가 315-100',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 감자탕',
#   'distance': '',
#   'id': '13289056',
#   'phone': '02-465-6580',
#   'place_name': '소문난성수감자탕',
#   'place_url': 'http://place.map.kakao.com/13289056',
#   'road_address_name': '서울 성동구 연무장길 45',
#   'x': '127.05440457812',
#   'y': '37.5428308422967'},
#  {'address_name': '서울 성동구 성수동2가 289-273',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 육류,고기 > 족발,보쌈',
#   'distance': '',
#   'id': '8416853',
#   'phone': '02-464-0425',
#   'place_name': '성수족발',
#   'place_url': 'http://place.map.kakao.com/8416853',
#   'road_address_name': '서울 성동구 아차산로7길 7',
#   'x': '127.05431637398702',
#   'y': '37.54602762815355'},
#  {'address_name': '서울 성동구 성수동2가 277-135',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페',
#   'distance': '',
#   'id': '145791269',
#   'phone': '070-4353-3238',
#   'place_name': '어니언 성수',
#   'place_url': 'http://place.map.kakao.com/145791269',
#   'road_address_name': '서울 성동구 아차산로9길 8',
#   'x': '127.05820807890457',
#   'y': '37.544782395189884'},
#  {'address_name': '서울 성동구 성수동2가 314-2',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페',
#   'distance': '',
#   'id': '1783691580',
#   'phone': '02-469-2122',
#   'place_name': '쎈느',
#   'place_url': 'http://place.map.kakao.com/1783691580',
#   'road_address_name': '서울 성동구 연무장5길 20',
#   'x': '127.05344423870629',
#   'y': '37.54489276727298'},
#  {'address_name': '서울 성동구 성수동2가 322-32',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 테마카페 > 갤러리카페',
#   'distance': '',
#   'id': '1128989913',
#   'phone': '0507-1390-9669',
#   'place_name': '성수동대림창고갤러리',
#   'place_url': 'http://place.map.kakao.com/1128989913',
#   'road_address_name': '서울 성동구 성수이로 78',
#   'x': '127.05624815815919',
#   'y': '37.54171994709006'},
#  {'address_name': '서울 성동구 성수동2가 309-133',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 테마카페 > 디저트카페',
#   'distance': '',
#   'id': '1301973155',
#   'phone': '010-3934-2301',
#   'place_name': '할아버지공장',
#   'place_url': 'http://place.map.kakao.com/1301973155',
#   'road_address_name': '서울 성동구 성수이로7가길 9',
#   'x': '127.054833289351',
#   'y': '37.54108991277329'},
#  {'address_name': '서울 성동구 성수동2가 302-16',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페',
#   'distance': '',
#   'id': '1302549042',
#   'phone': '070-8824-2010',
#   'place_name': '로우키',
#   'place_url': 'http://place.map.kakao.com/1302549042',
#   'road_address_name': '서울 성동구 연무장3길 6',
#   'x': '127.05157665819107',
#   'y': '37.5441908183721'},
#  {'address_name': '서울 성동구 성수동2가 315-49',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 일식',
#   'distance': '',
#   'id': '1155031193',
#   'phone': '02-6339-1552',
#   'place_name': '소바식당 성수점',
#   'place_url': 'http://place.map.kakao.com/1155031193',
#   'road_address_name': '서울 성동구 연무장7가길 6',
#   'x': '127.0550044286049',
#   'y': '37.543011665300575'},
#  {'address_name': '서울 성동구 성수동2가 302-8',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 양식 > 햄버거',
#   'distance': '',
#   'id': '936069123',
#   'phone': '02-2054-0119',
#   'place_name': '르프리크',
#   'place_url': 'http://place.map.kakao.com/936069123',
#   'road_address_name': '서울 성동구 연무장5길 9-16',
#   'x': '127.05265860726594',
#   'y': '37.544439016637995'},
#  {'address_name': '서울 성동구 성수동2가 277-156',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 육류,고기 > 삼겹살',
#   'distance': '',
#   'id': '475641876',
#   'phone': '02-465-0434',
#   'place_name': '잠수교집 성수점',
#   'place_url': 'http://place.map.kakao.com/475641876',
#   'road_address_name': '서울 성동구 아차산로 137',
#   'x': '127.05928683346377',
#   'y': '37.543815987333964'},
#  {'address_name': '서울 성동구 성수동2가 315-55',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페',
#   'distance': '',
#   'id': '1038283810',
#   'phone': '02-467-0303',
#   'place_name': '마를리',
#   'place_url': 'http://place.map.kakao.com/1038283810',
#   'road_address_name': '서울 성동구 연무장길 47',
#   'x': '127.054745135469',
#   'y': '37.5427802289338'},
#  {'address_name': '서울 성동구 성수동2가 328-15',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 양식',
#   'distance': '',
#   'id': '2092039626',
#   'phone': '0507-1349-9197',
#   'place_name': '성수다락',
#   'place_url': 'http://place.map.kakao.com/2092039626',
#   'road_address_name': '서울 성동구 뚝섬로9길 20',
#   'x': '127.05622417450184',
#   'y': '37.53991795897108'},
#  {'address_name': '서울 성동구 성수동1가 656-591',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 육류,고기 > 갈비',
#   'distance': '',
#   'id': '12055448',
#   'phone': '02-464-3012',
#   'place_name': '대성갈비',
#   'place_url': 'http://place.map.kakao.com/12055448',
#   'road_address_name': '서울 성동구 상원1길 26',
#   'x': '127.04823206777257',
#   'y': '37.5464294126438'},
#  {'address_name': '서울 성동구 성수동2가 315-41',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페',
#   'distance': '',
#   'id': '1942841428',
#   'phone': '070-8830-5994',
#   'place_name': '카페포제',
#   'place_url': 'http://place.map.kakao.com/1942841428',
#   'road_address_name': '서울 성동구 연무장9길 7',
#   'x': '127.05575119265147',
#   'y': '37.54293653214302'},
#  {'address_name': '서울 성동구 성수동2가 315-30',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 양식 > 이탈리안',
#   'distance': '',
#   'id': '12447534',
#   'phone': '0507-1428-9194',
#   'place_name': '까사아지오',
#   'place_url': 'http://place.map.kakao.com/12447534',
#   'road_address_name': '서울 성동구 연무장5가길 20',
#   'x': '127.05477837998508',
#   'y': '37.54336766514594'}]

# %%
from bs4 import BeautifulSoup

BeautifulSoup(requests.get("https://place.map.kakao.com/m/13289056#comment").content, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>소문난성수감자탕 | 카카오맵</title>
# <meta content="소문난성수감자탕" property="og:title"/>
# <meta content="카카오맵" property="og:site_name"/>
# <meta content="서울 성동구 연무장길 45 1층 (성수동2가 315-100)" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="http://map3.daum.net/staticmap/og?type=place&amp;srs=wcongnamul&amp;size=400x200&amp;m=512020%2C1123148&amp;service=placeweb" property="og:image"/>
# <meta content="https://place.map.kakao.com/m/13289056" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="소문난성수감자탕" name="twitter:title"/>
# <meta content="서울 성동구 연무장길 45 1층 (성수동2가 315-100)" name="twitter:description"/>
# <meta content="http://map3.daum.net/staticmap/og?type=place&amp;srs=wcongnamul&amp;size=400x200&amp;m=512020%2C1123148&amp;service=placeweb" name="twitter:image"/>
# <meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="//t1.daumcdn.net/localimg/localimages/07/common/kakaomap_favicon.ico" rel="shortcut icon"/>
# <link href="//t1.daumcdn.net/kakaomapweb/place/jscss/mobile.4a3c856b.css" rel="stylesheet" type="text/css">
# </link></head>
# <body data-os="unknown">
# <div id="kakaoIndex">
# <a href="#kakaoGnb">메뉴 바로가기</a>
# <a href="#kakaoContent">본문 바로가기</a>
# </div>
# <div class="map_detail" id="kakaoWrap" style="display: none;">
# <div class="floating_bnr hide" data-root="" data-viewid="leverageBanner">
# <div class="inner_floating">
# <a class="link_floating" data-logevent="gotoapp,detailinfo,floating-button" href="#none">
# <span class="ico_comm_fgm ico_kakaomap">kakaomap</span> <span class="txt_floating">앱 열기</span>
# </a>
# <a class="btn_close" href="#none"><span class="ico_comm_fgm ico_close">플로팅 배너 닫기</span></a>
# </div>
# </div>
# <hr class="hide"/>
# <div data-root="" data-viewid="footer">
# <span class="info_revise">
#             업데이트 2024.08.07.
#         </span>
# <div class="cont_footer" id="footContent">
# <a class="link_sresult" data-logevent="searchlist" data-logtarget="" href="//m.search.daum.net/search?q=%EC%86%8C%EB%AC%B8%EB%82%9C%EC%84%B1%EC%88%98%EA%B0%90%EC%9E%90%ED%83%95">Kakao 검색결과</a>
# <span class="link_rectify" style="color:#ddd;">정보 수정 제안</span>
# <a class="link_gotop" data-logevent="gotop" data-logtarget="" href="#none"><span class="ico_comm ico_gotop"></span>맨위로</a>
# </div>
# <footer class="k_foot" id="kakaoFoot">
# <small class="copr_info">
# <a class="link_kakaocorp" data-logevent="footer,copyright" data-logtarget="" href="http://m.kakaocorp.com/main"><span class="ico_copyright">ⓒ</span>Kakao</a>
# </small>
# <div class="info_foot">
# <a class="link_foot" href="https://cs.kakao.com/requests?locale=ko&amp;service=101">고객센터</a>
# <span class="txt_bar">|</span>
# <div id="daumMinidaum"><a class="minidaum_login" data-logevent="footer,loginout" data-logtarget="" href="#"><!-- 로그인/회원가입/로그아웃 --></a></div>
# </div>
# </footer>
# </div>
# <div class="dimmed_layer" data-root="" data-viewid="dimmedLayer"></div>
# </div>
# <div id="daumWrap" style="display:none;">
# <div id="daumContent">
# <div id="shareContainer"></div>
# </div>
# </div>
# <script src="//ssl.daumcdn.net/dmaps/map_js_init/v3.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/daumtop_deco/socialshare/socialshare_mo-2.5.1.js" type="text/javascript"></script>
# <script src="//m1.daumcdn.net/svc/original/U03/cssjs/userAgent/userAgent-1.0.12.min.js" type="text/javascript"></script>
# <script async="" charset="utf-8" src="//t1.daumcdn.net/kas/static/ba.min.js" type="text/javascript"></script>
# <script>
#         window.socialshareRenewal = 'undefined' !== typeof socialshareRenewal ? socialshareRenewal : {};
#
#         window.ENV = 'PROD';
#         // 티아라 초기화
#         try {
#             TiaraTracker.getInstance().init({
#                 svcDomain: 'm.place.map.kakao.com',
#                 deployment: window.ENV === 'PROD' ? 'production' : 'dev'
#             });
#         } catch(e) {}
#         window._cp = '';
#         window.placeRestrictType = 'NONE';
#         window.msaConfigChain = '949d0d4414084edab1da3bd7e8c522c2|5664';
#     </script>
# <script src="https://t1.daumcdn.net/kakaomapweb/place/lib/Chart_2.4.0.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/kakaomapweb/place/jscss/mobile.36659d81.js" type="text/javascript"></script>
# <!--
#     <script type="text/javascript" src="//go.daum.net/bin/minidaum_https.cgi?minidaum_mobile=y&js_url=minidaumMobile2011&viewport=320&tracker=off" charset="euc-kr"></script>
#     -->
# </body>
# </html>

# %% [markdown]
# ## comment 수집하기

# %%
COMMENT_URL = "https://place.map.kakao.com/m/commentlist/v/13289056/0?order=USEFUL&onlyPhotoComment=false"

comment_datas = requests.get(COMMENT_URL).json()
comment_datas
# Out:
# {'comment': {'placenamefull': '소문난성수감자탕',
#   'cid': 13289056,
#   'kamapComntcnt': 746,
#   'scoresum': 2268,
#   'scorecnt': 746,
#   'list': [{'commentid': '10762893',
#     'contents': '가서 먹은 것 : 뼈해장국1\n\n국물 맛 ☆☆☆\n국물은 다른 감자탕 집처럼 밥말아서 먹고 싶을 정도의 맛이다. \n고기 질 ☆\n이게 고기를 먹으러 온건지 뼈를 먹으러 온건지 모르겠다. 일단 살이 너무 없었다.\n고기 양 ☆\n시래기국에 고기 두덩이 들어가 있었다. 동네에서 사먹는 뼈해장국이 훨씬 나았지만 성수동이니까 라는 마음이었다.. \n지인 추천 ☆ \n안할듯 지인이랑 연끊고 싶으면 추천해줘도됨\n김치 맛 ☆☆\n감자탕 먹을 때 김치를 꼭 먹는 편인데 여긴 ...딱히 기억은 안남\n대기열 ☆\n왜 대기열이 많은지는 잘 모르겠다.. 다른데 걸어가서 먹는게 더 맛있음\n손님대응 ☆☆\n그냥 바쁘셔서 그런지 손님대응은 좋지않지만 성수동 젤 유명한 집이라서 이해가 됨\n\n그래서 이쪽동네 뼈해장국 집은 다 돌아다녀봤다.괜찮은곳은 2곳있었고 가격대비 최강인곳은 시장쪽에 있는 양은냄비에 끓여주시는 감자탕이 제일 맛있었다. 가격도 동네 앞에서 먹는 정도로 싼편이었고 (일단 만원 아래였음) 다른데를 더 추천 해주고싶다. ',
#     'point': 2,
#     'username': '권오성',
#     'profile': 'http://k.kakaocdn.net/dn/RQ8BA/btrdqjNbm6w/kTcxc0OnSIxFrmhz1huV3k/img_640x640.jpg',
#     'profileStatus': 'S',
#     'photoCnt': 0,
#     'likeCnt': 0,
#     'kakaoMapUserId': '1874603413',
#     'photoList': [],
#     'ownerReply': {},
#     'userCommentCount': 2,
#     'userCommentAverageScore': 3.5,
#     'myStorePick': False,
#     'level': {'nowLevel': 2, 'badge': '01'},
#     'date': '2024.08.13.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10755581',
#     'contents': '웨이팅까지는 좀 과한듯?',
#     'point': 3,
#     'username': 'le',
#     'profile': 'http://t1.daumcdn.net/local/kakaomapPhoto/profile/ced5781caa0179fc502efe02fc584f18cc1f9950?original',
#     'profileStatus': 'S',
#     'photoCnt': 0,
#     'likeCnt': 0,
#     'kakaoMapUserId': '1221285947',
#     'photoList': [],
#     'ownerReply': {},
#     'userCommentCount': 13,
#     'userCommentAverageScore': 2.8,
#     'myStorePick': False,
#     'level': {'nowLevel': 6, 'badge': '01'},
#     'date': '2024.08.12.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10753665',
#     'contents': '매번 웨이팅이 엄청 길어서 너무궁금했는데, 생각보다 평범한 맛이라서 놀랬음. 그냥 감자탕 맛!',
#     'point': 2,
#     'username': '냥델',
#     'profile': 'http://k.kakaocdn.net/dn/46iSW/btrkJmWDSdf/0WkwA3OlUf8mXnYzL5ymc1/img_640x640.jpg',
#     'profileStatus': 'S',
#     'photoCnt': 1,
#     'likeCnt': 0,
#     'thumbnail': 'http://t1.daumcdn.net/local/kakaomapPhoto/review/db244303d9d152f99a0f8f3e8550b6f807f78a7a?original',
#     'kakaoMapUserId': '1999595173',
#     'photoList': [{'url': 'http://t1.daumcdn.net/local/kakaomapPhoto/review/db244303d9d152f99a0f8f3e8550b6f807f78a7a?original',
#       'near': True}],
#     'ownerReply': {},
#     'userCommentCount': 75,
#     'userCommentAverageScore': 4.8,
#     'myStorePick': False,
#     'level': {'nowLevel': 31, 'badge': '03'},
#     'date': '2024.08.11.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10742888',
#     'contents': '양도 많지만 사람이 많다보니 응대가 조금 아쉽긴합니다. 처음엔 맛있었는데 몇 번 가니 물리는 느낌도.. 대기 없이 먹는 걸 추천합니다.',
#     'point': 4,
#     'username': '𖤐3추천4강추5단골',
#     'profile': 'http://th-p.talk.kakao.co.kr/th/talkp/wkCiZukMz4/zqODwWQG0VUQsa0fxRS15K/talkp.jpg',
#     'profileStatus': 'S',
#     'photoCnt': 0,
#     'likeCnt': 0,
#     'kakaoMapUserId': '338001077',
#     'photoList': [],
#     'ownerReply': {},
#     'userCommentCount': 98,
#     'userCommentAverageScore': 3.5,
#     'myStorePick': False,
#     'level': {'nowLevel': 28, 'badge': '02'},
#     'date': '2024.08.10.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10741409',
#     'contents': ' 대기줄에 비해 평범한 감자탕 맛입니다. 착석과 동시에 음식이 나와서 신기했어요. 식당 내부가 엄청 정신없어서 편하게 식사하진 못했습니다. ',
#     'point': 3,
#     'username': '감사합니다',
#     'profile': 'http://t1.daumcdn.net/local/kakaomapPhoto/profile/3333f7e6113624e7fabc0fbf8288f0344d54e3e7?original',
#     'profileStatus': 'S',
#     'photoCnt': 1,
#     'likeCnt': 0,
#     'thumbnail': 'http://t1.daumcdn.net/local/kakaomapPhoto/review/3a6de7a48e0652f627a4be5372a0c0fb476f283b?original',
#     'kakaoMapUserId': '2106920704',
#     'photoList': [{'url': 'http://t1.daumcdn.net/local/kakaomapPhoto/review/3a6de7a48e0652f627a4be5372a0c0fb476f283b?original',
#       'near': True}],
#     'ownerReply': {},
#     'userCommentCount': 116,
#     'userCommentAverageScore': 3.8,
#     'myStorePick': False,
#     'level': {'nowLevel': 32, 'badge': '03'},
#     'date': '2024.08.10.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10731239',
#     'contents': '넘넘 맛있게 먹었어요~왜 이렿게 대기줄이 긴지 알겠네요~오픈시간 맞춰 일찍 가서 바로 입장해서 먹으니 좋아요~',
#     'point': 5,
#     'username': '용미',
#     'profile': 'http://th-p.talk.kakao.co.kr/th/talkp/wkFys7ElmS/3GkGKbXJa8Y9cpBbuoKsE0/7jc20l.jpg',
#     'profileStatus': 'S',
#     'photoCnt': 0,
#     'likeCnt': 0,
#     'kakaoMapUserId': '263535028',
#     'photoList': [],
#     'ownerReply': {},
#     'strengths': [{'id': 5, 'name': '맛'}, {'id': 1, 'name': '가성비'}],
#     'userCommentCount': 6,
#     'userCommentAverageScore': 5.0,
#     'myStorePick': False,
#     'level': {'nowLevel': 6, 'badge': '01'},
#     'date': '2024.08.09.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10717318',
#     'point': 3,
#     'username': '이민준',
#     'profile': 'https://p.kakaocdn.net/th/talkp/woHDbIed6N/UnoAtXBz0JVlYgElOalVpk/wsn3jl_640x640_s.jpg',
#     'profileStatus': 'S',
#     'photoCnt': 0,
#     'likeCnt': 0,
#     'kakaoMapUserId': '1264400659',
#     'photoList': [],
#     'ownerReply': {},
#     'userCommentCount': 4,
#     'userCommentAverageScore': 4.5,
#     'myStorePick': False,
#     'level': {'nowLevel': 4, 'badge': '01'},
#     'date': '2024.08.07.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10708675',
#     'contents': '또 먹으러가고 싶은집',
#     'point': 5,
#     'username': '만두',
#     'profile': 'http://t1.daumcdn.net/local/kakaomapPhoto/profile/9a2743c2e2e066b27ad90603d4b0effda0ff75f8?original',
#     'profileStatus': 'S',
#     'photoCnt': 0,
#     'likeCnt': 0,
#     'kakaoMapUserId': '1472265051',
#     'photoList': [],
#     'ownerReply': {},
#     'userCommentCount': 21,
#     'userCommentAverageScore': 4.0,
#     'myStorePick': False,
#     'level': {'nowLevel': 10, 'badge': '01'},
#     'date': '2024.08.06.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10708190',
#     'contents': '낫배드입니당 우리가 아는 그 맛!\n몇 시간 씩 기다릴 필요는 절 ~ 대 ㄴㄴ',
#     'point': 5,
#     'username': 'cinamonee',
#     'profile': 'http://t1.daumcdn.net/local/kakaomapPhoto/profile/50254f7b593325cd78fbc49f7e488e2706815393?original',
#     'profileStatus': 'S',
#     'photoCnt': 2,
#     'likeCnt': 0,
#     'thumbnail': 'http://t1.daumcdn.net/local/kakaomapPhoto/review/8994474fa9abdd7e9ff928c3c3588094a9de121f?original',
#     'kakaoMapUserId': '1787518765',
#     'photoList': [{'url': 'http://t1.daumcdn.net/local/kakaomapPhoto/review/8994474fa9abdd7e9ff928c3c3588094a9de121f?original',
#       'near': False},
#      {'url': 'http://t1.daumcdn.net/local/kakaomapPhoto/review/0790cd2c3c28146d91bbee612713755742b05c53?original',
#       'near': False}],
#     'ownerReply': {},
#     'userCommentCount': 257,
#     'userCommentAverageScore': 4.7,
#     'myStorePick': False,
#     'level': {'nowLevel': 49, 'badge': '03'},
#     'date': '2024.08.05.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False},
#    {'commentid': '10702987',
#     'contents': '감자국식사를 시킬것',
#     'point': 4,
#     'username': '민쉐린',
#     'profile': 'https://p.kakaocdn.net/th/talkp/woAJB72NKZ/2o322UdikjoOgUR2WTKbSK/pmjlf8_640x640_s.jpg',
#     'profileStatus': 'S',
#     'photoCnt': 0,
#     'likeCnt': 0,
#     'kakaoMapUserId': '1361685899',
#     'photoList': [],
#     'ownerReply': {},
#     'userCommentCount': 193,
#     'userCommentAverageScore': 3.7,
#     'myStorePick': False,
#     'level': {'nowLevel': 35, 'badge': '03'},
#     'date': '2024.08.05.',
#     'isMy': False,
#     'isBlock': False,
#     'isEditable': False,
#     'isMyLike': False}],
#   'strengthCounts': [{'id': 5, 'name': '맛', 'count': 135},
#    {'id': 1, 'name': '가성비', 'count': 83},
#    {'id': 2, 'name': '친절', 'count': 29},
#    {'id': 3, 'name': '분위기', 'count': 22},
#    {'id': 4, 'name': '주차', 'count': 14}],
#   'hasNext': True,
#   'reviewWriteBlocked': 'NONE'}}

# %%
# 각 가게에 부여된 id와 마지막 comment id 를 넣을 수 있게 format 삽입
COMMENT_URL = "https://place.map.kakao.com/m/commentlist/v/{}/{}?order=USEFUL&onlyPhotoComment=false"

# %%
ids = [d['id'] for d in data]
ids
# Out:
# ['13289056',
#  '8416853',
#  '145791269',
#  '1783691580',
#  '1128989913',
#  '1301973155',
#  '1302549042',
#  '1155031193',
#  '936069123',
#  '475641876',
#  '1038283810',
#  '2092039626',
#  '12055448',
#  '1942841428',
#  '12447534']

# %%
all_comments = []
for id in ids[:3]:
    # 첫 번쨰 코멘트의 id는 무조건 0
    comment_id = 0

    # has_next가 true 면 마지막 코멘트 id를 새롭게 넣어 계속 크롤링
    has_next = True

    while has_next:
        # 수집해야 할 url 설정
        SCRAP_COMMENT_URL = COMMENT_URL.format(id, comment_id)
        # 만들어진 url로 요청
        response = requests.get(SCRAP_COMMENT_URL)
        comment_data = response.json()['comment']
        # 댓글 데이터 가져오기
        comment_list = comment_data['list']
        all_comments.extend(comment_list) # 1차원 배열로 쭉 이어붙이기
        # 다음 페이지 존재 여부 확인
        has_next = comment_data['hasNext']
        # has_next 가 True 인 경우 마지막 코멘트의 id를 comment_id로 설정
        if has_next:
            comment_id = comment_list[-1]['commentid']

        print(comment_list)

all_comments

# %%
import pandas as pd

comment_df = pd.DataFrame(all_comments)
comment_df.head()
# Out:
#   commentid                                           contents  point  \
# 0  10762893  가서 먹은 것 : 뼈해장국1\n\n국물 맛 ☆☆☆\n국물은 다른 감자탕 집처럼 밥말...      2
# 1  10755581                                      웨이팅까지는 좀 과한듯?      3
# 2  10753665  매번 웨이팅이 엄청 길어서 너무궁금했는데, 생각보다 평범한 맛이라서 놀랬음. 그냥 ...      2
# 3  10742888  양도 많지만 사람이 많다보니 응대가 조금 아쉽긴합니다. 처음엔 맛있었는데 몇 번 가...      4
# 4  10741409   대기줄에 비해 평범한 감자탕 맛입니다. 착석과 동시에 음식이 나와서 신기했어요. ...      3
#
#      username                                            profile  \
# 0         권오성  http://k.kakaocdn.net/dn/RQ8BA/btrdqjNbm6w/kTc...
# 1          le  http://t1.daumcdn.net/local/kakaomapPhoto/prof...
# 2          냥델  http://k.kakaocdn.net/dn/46iSW/btrkJmWDSdf/0Wk...
# 3  𖤐3추천4강추5단골  http://th-p.talk.kakao.co.kr/th/talkp/wkCiZukM...
# 4       감사합니다  http://t1.daumcdn.net/local/kakaomapPhoto/prof...
#
#   profileStatus  photoCnt  likeCnt kakaoMapUserId  \
# 0             S         0        0     1874603413
# 1             S         0        0     1221285947
# 2             S         1        0     1999595173
# 3             S         0        0      338001077
# 4             S         1        0     2106920704
#
#                                            photoList  ...  \
# 0                                                 []  ...
# 1                                                 []  ...
# 2  [{'url': 'http://t1.daumcdn.net/local/kakaomap...  ...
# 3                                                 []  ...
# 4  [{'url': 'http://t1.daumcdn.net/local/kakaomap...  ...
#
#   userCommentAverageScore  myStorePick                            level  \
# 0                     3.5        False   {'nowLevel': 2, 'badge': '01'}
# 1                     2.8        False   {'nowLevel': 6, 'badge': '01'}
# 2                     4.8        False  {'nowLevel': 31, 'badge': '03'}
# 3                     3.5        False  {'nowLevel': 28, 'badge': '02'}
# 4                     3.8        False  {'nowLevel': 32, 'badge': '03'}
#
#           date   isMy isBlock  isEditable  isMyLike  \
# 0  2024.08.13.  False   False       False     False
# 1  2024.08.12.  False   False       False     False
# 2  2024.08.11.  False   False       False     False
# 3  2024.08.10.  False   False       False     False
# 4  2024.08.10.  False   False       False     False
#
#                                            thumbnail  strengths
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2  http://t1.daumcdn.net/local/kakaomapPhoto/revi...        NaN
# 3                                                NaN        NaN
# 4  http://t1.daumcdn.net/local/kakaomapPhoto/revi...        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 분류모델 만들기
# * 수집한 데이터를 토대로 전처리

# %%
from konlpy.tag import Okt

okt= Okt()
def my_tokenizer(sentence):
    return okt.morphs(sentence, stem=True, norm=True)

# %%
# 4점 이상은 긍정(0)
# 3점 이상은 중립(1)
# 3점 미만은 부정(2)

def get_category_sentiment(point):
  if point >= 4: return 0
  elif point >=3 : return 1
  else : return 2

comment_df['target'] = comment_df['point'].apply(get_category_sentiment)
comment_df.head()
# Out:
#   commentid                                           contents  point  \
# 0  10762893  가서 먹은 것 : 뼈해장국1\n\n국물 맛 ☆☆☆\n국물은 다른 감자탕 집처럼 밥말...      2
# 1  10755581                                      웨이팅까지는 좀 과한듯?      3
# 2  10753665  매번 웨이팅이 엄청 길어서 너무궁금했는데, 생각보다 평범한 맛이라서 놀랬음. 그냥 ...      2
# 3  10742888  양도 많지만 사람이 많다보니 응대가 조금 아쉽긴합니다. 처음엔 맛있었는데 몇 번 가...      4
# 4  10741409   대기줄에 비해 평범한 감자탕 맛입니다. 착석과 동시에 음식이 나와서 신기했어요. ...      3
#
#      username                                            profile  \
# 0         권오성  http://k.kakaocdn.net/dn/RQ8BA/btrdqjNbm6w/kTc...
# 1          le  http://t1.daumcdn.net/local/kakaomapPhoto/prof...
# 2          냥델  http://k.kakaocdn.net/dn/46iSW/btrkJmWDSdf/0Wk...
# 3  𖤐3추천4강추5단골  http://th-p.talk.kakao.co.kr/th/talkp/wkCiZukM...
# 4       감사합니다  http://t1.daumcdn.net/local/kakaomapPhoto/prof...
#
#   profileStatus  photoCnt  likeCnt kakaoMapUserId  \
# 0             S         0        0     1874603413
# 1             S         0        0     1221285947
# 2             S         1        0     1999595173
# 3             S         0        0      338001077
# 4             S         1        0     2106920704
#
#                                            photoList  ... myStorePick  \
# 0                                                 []  ...       False
# 1                                                 []  ...       False
# 2  [{'url': 'http://t1.daumcdn.net/local/kakaomap...  ...       False
# 3                                                 []  ...       False
# 4  [{'url': 'http://t1.daumcdn.net/local/kakaomap...  ...       False
#
#                              level         date   isMy isBlock isEditable  \
# 0   {'nowLevel': 2, 'badge': '01'}  2024.08.13.  False   False      False
# 1   {'nowLevel': 6, 'badge': '01'}  2024.08.12.  False   False      False
# 2  {'nowLevel': 31, 'badge': '03'}  2024.08.11.  False   False      False
# 3  {'nowLevel': 28, 'badge': '02'}  2024.08.10.  False   False      False
# 4  {'nowLevel': 32, 'badge': '03'}  2024.08.10.  False   False      False
#
#    isMyLike                                          thumbnail  strengths  \
# 0     False                                                NaN        NaN
# 1     False                                                NaN        NaN
# 2     False  http://t1.daumcdn.net/local/kakaomapPhoto/revi...        NaN
# 3     False                                                NaN        NaN
# 4     False  http://t1.daumcdn.net/local/kakaomapPhoto/revi...        NaN
#
#    target
# 0       2
# 1       1
# 2       2
# 3       0
# 4       1
#
# [5 rows x 23 columns]

# %%
comment_df.dropna(how='any', subset=['contents'], inplace=True)
comment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1231 entries, 0 to 1280
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   commentid                1231 non-null   object
#  1   contents                 1231 non-null   object
#  2   point                    1231 non-null   int64
#  3   username                 1229 non-null   object
#  4   profile                  1182 non-null   object
#  5   profileStatus            1231 non-null   object
#  6   photoCnt                 1231 non-null   int64
#  7   likeCnt                  1231 non-null   int64
#  8   kakaoMapUserId           1231 non-null   object
#  9   photoList                1231 non-null   object
#  10  ownerReply               1231 non-null   object
#  11  userCommentCount         1231 non-null   int64
#  12  userCommentAverageScore  1231 non-null   float64
#  13  myStorePick              1231 non-null   bool
#  14  level                    1231 non-null   object
#  15  date                     1231 non-null   object
#  16  isMy                     1231 non-null   bool
#  17  isBlock                  1231 non-null   bool
#  18  isEditable               1231 non-null   bool
#  19  isMyLike                 1231 non-null   bool
#  20  thumbnail                366 non-null    object
#  21  strengths                258 non-null    object
#  22  target                   1231 non-null   int64
# dtypes: bool(5), float64(1), int64(5), object(12)
# memory usage: 188.7+ KB

# %%
# 정규식을 통한 한글만 남을 수 있게 정제
import re

comment_df['preprocessed_comment'] = comment_df['contents'].apply(lambda s : re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", s))
comment_df[['contents', 'preprocessed_comment']].head()
# Out:
#                                             contents  \
# 0  가서 먹은 것 : 뼈해장국1\n\n국물 맛 ☆☆☆\n국물은 다른 감자탕 집처럼 밥말...
# 1                                      웨이팅까지는 좀 과한듯?
# 2  매번 웨이팅이 엄청 길어서 너무궁금했는데, 생각보다 평범한 맛이라서 놀랬음. 그냥 ...
# 3  양도 많지만 사람이 많다보니 응대가 조금 아쉽긴합니다. 처음엔 맛있었는데 몇 번 가...
# 4   대기줄에 비해 평범한 감자탕 맛입니다. 착석과 동시에 음식이 나와서 신기했어요. ...
#
#                                 preprocessed_comment
# 0  가서 먹은 것  뼈해장국국물 맛 국물은 다른 감자탕 집처럼 밥말아서 먹고 싶을 정도...
# 1                                       웨이팅까지는 좀 과한듯
# 2  매번 웨이팅이 엄청 길어서 너무궁금했는데 생각보다 평범한 맛이라서 놀랬음 그냥 감자탕 맛
# 3  양도 많지만 사람이 많다보니 응대가 조금 아쉽긴합니다 처음엔 맛있었는데 몇 번 가니...
# 4   대기줄에 비해 평범한 감자탕 맛입니다 착석과 동시에 음식이 나와서 신기했어요 식당...

# %%
comment_df['target'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='target'>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(
    tokenizer = my_tokenizer
    # 실제로 만들 때는 단어 빈도수 등 확인하고 파라미터 추가
)

X = tfidf_vectorizer.fit_transform(comment_df['preprocessed_comment'])
y = comment_df['target']
# Out:
# C:\Users\user\.conda\envs\ml-env\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
from sklearn.linear_model import LogisticRegression

log_clf = LogisticRegression()
log_clf.fit(X, y)
# Out:
# LogisticRegression()

# %%
def sentiment_predict(sentence):
  sentence_norm_stem = okt.morphs(sentence, stem=True, norm=True)
  sentence_test = ' '.join(sentence_norm_stem)

  text_vector = tfidf_vectorizer.transform([sentence_test])

  pred = log_clf.predict(text_vector)
  print(sentence, "====>", pred)

# %%
sentiment_predict('위생은 좀 더럽지만 맛은 괜찮았어요')
# Out:
# 위생은 좀 더럽지만 맛은 괜찮았어요 ====> [1]

# %%
sentiment_predict('와 존맛탱')
# Out:
# 와 존맛탱 ====> [0]
